# %% [markdown]
# # `MAPAS`

# %% [markdown]
# ## Ejemplo 1
#
# Crear un array

# %%
archivo_mexico = "mexico-251207.osm.pbf"
# Out:
# 📂 Leyendo carreteras de todo México...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 23
#      21 print("📂 Leyendo carreteras de todo México...")
#      22 handler = RoadsHandler()
# ---> 23 handler.apply_file(archivo_mexico, locations=True)
#      25 # Convertir a GeoDataFrame
#      26 gdf_roads = gpd.GeoDataFrame(geometry=handler.roads, crs="EPSG:4326")
#
# File c:\Users\hm9474\OneDrive - AT&T Mexico\Escritorio\proyectos\tutorialPython\venv\Lib\site-packages\osmium\simple_handler.py:61, in SimpleHandler.apply_file(self, filename, locations, idx, filters)
#      50 def apply_file(self, filename: Union[str, 'os.PathLike[str]', File],
#      51                locations: bool = False, idx: str = 'flex_mem',
#      52                filters: List['HandlerLike'] = []) -> None:
#      53     """ Apply the handler to the given file. If locations is true, then
# ...

# %%
#Mostrar Dimension del Array
print("Dimension del Array: ", a.ndim)
# Out:
# Dimension del Array:  2

# %%
# Mostrar los elementos del array
print("Numero de elementos del array: ", a.size)
# Out:
# Numero de elementos del array 6

# %%
# Mostrar Forma del array
print("forma del Array: ", a.shape)
# Out:
# forma del Array:  (2, 3)

# %%
# Mostrar el tipo del Array
print("Tipo de dato del Array: ", a.dtype)
# Out:
# Tipo de dato del Array:  int64

# %% [markdown]
# ## `Ejemplo 2`
#
# Crear otro array para realizar operaciones como la suma, y el producto

# %%
import numpy as np

a = np.array([[1, 2, 3], [4, 5, 6]])
b = np.array([[1, 1, 3], [2, 1, 3]])

print("La suma de el arreglo a y array b: ", a + b )
# Out:
# La suma de el arreglo a y array b:  [[2 3 6]
#  [6 6 9]]
